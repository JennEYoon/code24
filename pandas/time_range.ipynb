# %% [markdown]
# <a href="https://colab.research.google.com/github/JennEYoon/code24/blob/main/pandas/time_range.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas Practice, Time Range

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dates = pd.date_range('2023/10/01 5:30pm', periods=12, freq='H')
# 12 hours
print(dates)
# Out:
# DatetimeIndex(['2023-10-01 17:30:00', '2023-10-01 18:30:00',
#                '2023-10-01 19:30:00', '2023-10-01 20:30:00',
#                '2023-10-01 21:30:00', '2023-10-01 22:30:00',
#                '2023-10-01 23:30:00', '2023-10-02 00:30:00',
#                '2023-10-02 01:30:00', '2023-10-02 02:30:00',
#                '2023-10-02 03:30:00', '2023-10-02 04:30:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
temperatures = [4.4,5.1,6.1,6.2,6.1,6.1,5.7,5.2,4.7,4.1,3.9,3.5]
# 12 data points
s7 = pd.Series(temperatures, name="Temperature")
s7.plot()
plt.show()

# %%
temp_series = pd.Series(temperatures, dates)
temp_series
# Out:
# 2023-10-01 17:30:00    4.4
# 2023-10-01 18:30:00    5.1
# 2023-10-01 19:30:00    6.1
# 2023-10-01 20:30:00    6.2
# 2023-10-01 21:30:00    6.1
# 2023-10-01 22:30:00    6.1
# 2023-10-01 23:30:00    5.7
# 2023-10-02 00:30:00    5.2
# 2023-10-02 01:30:00    4.7
# 2023-10-02 02:30:00    4.1
# 2023-10-02 03:30:00    3.9
# 2023-10-02 04:30:00    3.5
# Freq: H, dtype: float64

# %%
temp_series.plot(kind="bar")
# plot temperature using hours.
plt.grid(True)
plt.show()

# %%
# Resampling, every 2 hours
temp_series_freq_2H = temp_series.resample("2H")
temp_series_freq_2H
temp_series_freq_2H = temp_series_freq_2H.mean()
# run by call ing mean every 2 hours

# %%
temp_series_freq_2H.plot(kind="bar")
plt.show()
